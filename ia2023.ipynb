# %% [markdown]
# # Tutoriel d'usage de l'API

# %% [markdown]
# Description de l'API
#
# - city : Nom de la ville où effectuer la recherche d’hôtels. Valeurs : ‘amsterdam’, ‘copenhagen’, ‘madrid’, ‘paris’, ‘rome’, ‘sofia’, ‘valletta’, ‘vienna’ et ‘vilnius’
#
# - date : Nombre de jours entre la date de la requête et le jour requêté (i.e. le nombre de jour entre le moment où vous regardez sur le site et le jour du check-in). Valeurs : Nombres positifs (entre 44 et 0).
#
# - language : Langue de l’interface. Valeurs : ‘austrian’, ‘bulgarian’, ‘croatian’, ‘cypriot’, ‘czech’, ‘danish’, ‘dutch’, ‘estonian’, ‘finnish’, ‘french’, ‘german’, ‘greek’, ‘hungarian’, ‘irish’, ‘italian’, ‘latvian’, ‘lithuanian’, ‘luxembourgish’, ‘maltese’, ‘polish’, ‘portuguese’, ‘romanian’, ‘slovakian’, ‘slovene’, ‘spanish’ or ‘swedish’.
# - mobile : Paramètre permettant de simuler une requête réalisée depuis un téléphone portable (au lieu d’un ordinateur). Valeurs : 1 (téléphone) ou 0 (ordinateur).
# - avatar : Identifiant d’un utilisateur fictif (e.g. un faux compte client créé).
#
# Chaque réponse de l'API sera composée de:
#
# - La liste des hôtels présents, comprenant pour chaque hôtel retourné 3 valeurs : l'ID de l'hôtel, le prix, le nombre de chambres restantes.
# - Un dictionnaire de certaines caractéristiques liées à la requête (vous pouvez aussi stocker vous-même les requêtes que vous faites et ignorer cette partie).

# %% [markdown]
# 1 avatar peut utiliser plusieurs langues

# %%
domain = "51.91.251.0"
port = 3000
host = f"http://{domain}:{port}"
path = lambda x: urllib.parse.urljoin(host, x)

# %%
# librairies
# --------------------------------------------
from datetime import datetime
import pandas
import numpy as np
import json
import csv
import requests
import pandas as pd

# %% [markdown]
# ## Creating an avatar

# %% [markdown]
# The admin of the competition can create users. A user can then create as many avatars as they wish.

# %%
import requests

user_id = 'f80b400f-3d29-43f0-8049-214a756ff0b3' # notre user ID reçu par mail
date = datetime.today().strftime('%Y-%m-%d_%H:%M:%S')
name1 = date + '_avatar'
#r = requests.post(path(f'avatars/{user_id}/{name1}'))
#r

# %%
'''date = datetime.today().strftime('%Y-%m-%d_%H:%M:%S')
name2 = date + '_avatar'
r = requests.post(path(f"avatars/{user_id}/{name}"))
r '''
# Out:
# <Response [200]>

# %%
r = requests.get(path(f"avatars/{user_id}"))
for avatar in r.json():
    print(avatar['id'], avatar['name'])
# Out:
# 5 max-first-avatar
# 6 max-second-avatar

# %% [markdown]
# ## Making pricing requests

# %%
params = {
    "avatar_name": name1,
    "language": "hungarian",
    "city": "copenhagen",
    "date": 2,
    "mobile": 0,
}
r1 = requests.get(path(f"pricing/{user_id}"), params=params)
r1.json()
# Out:
# {'prices': [{'hotel_id': 720, 'price': 467, 'stock': 2},
#   {'hotel_id': 434, 'price': 114, 'stock': 0},
#   {'hotel_id': 349, 'price': 317, 'stock': 1},
#   {'hotel_id': 367, 'price': 96, 'stock': 0},
#   {'hotel_id': 952, 'price': 94, 'stock': 0},
#   {'hotel_id': 528, 'price': 432, 'stock': 2},
#   {'hotel_id': 990, 'price': 168, 'stock': 0},
#   {'hotel_id': 60, 'price': 94, 'stock': 0},
#   {'hotel_id': 834, 'price': 91, 'stock': 0},
#   {'hotel_id': 757, 'price': 151, 'stock': 1},
#   {'hotel_id': 531, 'price': 204, 'stock': 2},
#   {'hotel_id': 772, 'price': 327, 'stock': 0},
#   {'hotel_id': 664, 'price': 472, 'stock': 2},
#   {'hotel_id': 332, 'price': 333, 'stock': 1},
#   {'hotel_id': 113, 'price': 89, 'stock': 0},
#   {'hotel_id': 445, 'price': 89, 'stock': 0},
#   {'hotel_id': 695, 'price': 202, 'stock': 2},
#   {'hotel_id': 142, 'price': 390, 'stock': 4},
#   {'hotel_id': 547, 'price': 202, 'stock': 2},
#   {'hotel_id': 793, 'price': 167, 'stock': 0},
# ...

# %%
A=np.array(lst)
A=np.reshape(A, (-1,3))
np.shape(A)
print(A)
# Out:
# [['0' 'austrian' 'amsterdam']
#  ['1' 'austrian' 'amsterdam']
#  ['0' 'austrian' 'copenhagen']
#  ...
#  ['1' 'swedish' 'vienna']
#  ['0' 'swedish' 'vilnius']
#  ['1' 'swedish' 'vilnius']]

# %%
df.iloc[4383,]
# Out:
# city                    rome
# language             cypriot
# mobile                     0
# already_used               1
# days            [14, 30, 38]
# Name: 4383, dtype: object

# %%
(sorted(days, reverse=True))
# Out:
# [24, 17, 16]

# %%
params = {
    "avatar_name": name1,
    "language": "hungarian",
    "city": "copenhagen",
    "date": 3,
    "mobile": 0,
}
r = requests.get(path(f"pricing/{user_id}"), params=params)
r.status_code, r.json()['detail']
# Out:
# (422, 'A pricing request for this avatar already exists for a sooner date')

# %%
params = {
    "avatar_name": name2,
    "language": "hungarian",
    "city": "amsterdam",
    "date": 1,
    "mobile": 1,
}
r2 = requests.get(path(f"pricing/{user_id}"), params=params)
r2.json()
# Out:
# {'prices': [{'hotel_id': 12, 'price': 76, 'stock': 0},
#   {'hotel_id': 567, 'price': 89, 'stock': 0},
#   {'hotel_id': 630, 'price': 150, 'stock': 0},
#   {'hotel_id': 307, 'price': 123, 'stock': 0},
#   {'hotel_id': 807, 'price': 396, 'stock': 1},
#   {'hotel_id': 317, 'price': 182, 'stock': 1},
#   {'hotel_id': 809, 'price': 396, 'stock': 1},
#   {'hotel_id': 269, 'price': 148, 'stock': 0},
#   {'hotel_id': 821, 'price': 107, 'stock': 0},
#   {'hotel_id': 441, 'price': 190, 'stock': 1},
#   {'hotel_id': 603, 'price': 349, 'stock': 1},
#   {'hotel_id': 557, 'price': 109, 'stock': 0},
#   {'hotel_id': 588, 'price': 169, 'stock': 0},
#   {'hotel_id': 211, 'price': 144, 'stock': 0},
#   {'hotel_id': 657, 'price': 250, 'stock': 1},
#   {'hotel_id': 517, 'price': 168, 'stock': 0},
#   {'hotel_id': 85, 'price': 153, 'stock': 0},
#   {'hotel_id': 271, 'price': 79, 'stock': 0},
#   {'hotel_id': 103, 'price': 176, 'stock': 7},
#   {'hotel_id': 163, 'price': 283, 'stock': 1},
# ...

# %% [markdown]
# ## Build a training set

# %%
import pandas as pd

pricing_requests = []

requests = [r1, r2]
for r in requests:
    pricing_requests.append(
        pd.DataFrame(r.json()['prices']).assign(**r.json()['request'])
    )

pricing_requests = pd.concat(pricing_requests)
pricing_requests.head()
# Out:
#    hotel_id  price  stock        city  date   language  mobile  avatar_id
# 0       720    467      2  copenhagen     2  hungarian       0          5
# 1       434    114      0  copenhagen     2  hungarian       0          5
# 2       349    317      1  copenhagen     2  hungarian       0          5
# 3       367     96      0  copenhagen     2  hungarian       0          5
# 4       952     94      0  copenhagen     2  hungarian       0          5

# %% [markdown]
# On va stocker en picke, 1000 requêtes par 1000 requêtes. \
# Ajouter la date de la requête au dataframe \
# Ajouter le nom de l'avatar au dataframe. \
# Creer une feature supplémentaire: cb de fois la mm recherche a été faite

# %%
len(pricing_requests)
# Out:
# 255

# %%
hotels = pd.read_csv('../input/defi-ia-2023/features_hotels.csv', index_col=['hotel_id', 'city'])
pricing_requests = pricing_requests.join(hotels, on=['hotel_id', 'city'])
pricing_requests.head()
# Out:
#    hotel_id  price  stock        city  date   language  mobile  avatar_id  \
# 0       720    467      2  copenhagen     2  hungarian       0          5
# 1       434    114      0  copenhagen     2  hungarian       0          5
# 2       349    317      1  copenhagen     2  hungarian       0          5
# 3       367     96      0  copenhagen     2  hungarian       0          5
# 4       952     94      0  copenhagen     2  hungarian       0          5
#
#                 group             brand  parking  pool  children_policy
# 0  Chillton Worldwide  Chill Garden Inn        0     0                2
# 1        Accar Hotels              Ibas        0     0                0
# 2            Yin Yang       Royal Lotus        0     1                0
# 3            Yin Yang         8 Premium        0     0                0
# 4         Independant       Independant        0     0                0

# %%
sample_submission = pd.read_csv('../input/defi-ia-2023/sample_submission.csv')
sample_submission.head()
# Out:
#    index  price
# 0      0  191.0
# 1      1  191.0
# 2      2  191.0
# 3      3  191.0
# 4      4  191.0

# %%
sample_submission.to_csv('submission.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [19], in <cell line: 1>()
# ----> 1 sample_submission.to_csv('submission.csv', index=False)
#
# NameError: name 'sample_submission' is not defined

# %% [markdown]
# ### NOS REQUETES

# %%
import pandas 
"""df = pandas.read_csv('./Defi-IA-bedbugs/test_set.csv', header = 0)
df2 = pandas.read_csv('./Defi-IA-bedbugs/features_hotels.csv', header = 0)
print(df)
print(df.shape[0])
pandas.merge(left=df, right=df2, how='left', left_on='hotel_id', right_on='hotel_id')"""
# Out:
# "df = pandas.read_csv('./Defi-IA-bedbugs/test_set.csv', header = 0)\ndf2 = pandas.read_csv('./Defi-IA-bedbugs/features_hotels.csv', header = 0)\nprint(df)\nprint(df.shape[0])\npandas.merge(left=df, right=df2, how='left', left_on='hotel_id', right_on='hotel_id')"

# %%
lst1=[0,1]   
lst2=['austrian', 'bulgarian', 'croatian', 'cypriot', 'czech', 'danish', 'dutch', 'estonian', 'finnish', 'french', 'german', 'greek', 'hungarian', 'irish', 'italian', 'latvian', 'lithuanian', 'luxembourgish', 'maltese', 'polish', 'portuguese', 'romanian', 'slovakian', 'slovene', 'spanish','swedish']
lst3=['amsterdam', 'copenhagen', 'madrid','paris', 'rome', 'sofia', 'valletta', 'vienna', 'vilnius']
print(len(lst2))
lst = [[[j,k,l] for j in lst1] for k in lst2 for l in lst3]
# Out:
# 26

# %%
A=np.array(lst)
A=np.reshape(A, (-1,3))
all_requests=pandas.DataFrame(A, columns=["mobile", "language", "city"])
all_requests
# Out:
#     mobile  language        city
# 0        0  austrian   amsterdam
# 1        1  austrian   amsterdam
# 2        0  austrian  copenhagen
# 3        1  austrian  copenhagen
# 4        0  austrian      madrid
# ..     ...       ...         ...
# 463      1   swedish    valletta
# 464      0   swedish      vienna
# 465      1   swedish      vienna
# 466      0   swedish     vilnius
# 467      1   swedish     vilnius
#
# [468 rows x 3 columns]

# %%
all_requests.to_csv('allrequest.csv', index=False)

# %%
number_days = 1

csv_name_all_permutation='allrequest.csv'

#à faire lors de la première utilisation 
#1) lecture du csv 
df = pandas.read_csv(csv_name_all_permutation, header = 0)

print(df)
# Out:
#      mobile  language        city
# 0         0  austrian   amsterdam
# 1         1  austrian   amsterdam
# 2         0  austrian  copenhagen
# 3         1  austrian  copenhagen
# 4         0  austrian      madrid
# ..      ...       ...         ...
# 463       1   swedish    valletta
# 464       0   swedish      vienna
# 465       1   swedish      vienna
# 466       0   swedish     vilnius
# 467       1   swedish     vilnius
#
# [468 rows x 3 columns]

# %%
#concaténer deux dataframes

our_requests1=pandas.DataFrame([[-1, 'belge', 'french', "paris", [1,2],  1]], columns=["avatar_id", "mobile", "language", "city", "date", "id_request"])

our_requests2=pandas.DataFrame([[-1, 'belgedd', 'french', "paris", [1,2],  1]], columns=["avatar_id", "mobile", "language", "city", "date", "id_request"])
"""pandas.concat([-1, 'belge', 'french', "paris", 0,  1])"""

our_requests3=pandas.DataFrame(columns=["avatar_id", "mobile", "language", "city", "date", "id_request"])
our_requests=pandas.concat([our_requests1, our_requests2],  ignore_index=True)

our_requests
# Out:
#    avatar_id   mobile language   city    date  id_request
# 0         -1    belge   french  paris  [1, 2]           1
# 1         -1  belgedd   french  paris  [1, 2]           1

# %%
"""all_our_requests=pandas.DataFrame(columns=["avatar_id", "mobile", "language", "city", "date", "id_request"])
all_our_requests.to_csv('all_our_requests_done.csv', index=False)

print(all_our_requests)"""
# Out:
# Empty DataFrame
# Columns: [avatar_id, mobile, language, city, date, id_request]
# Index: []

# %%
#création du fichier des résultats des requêtes
"""pricing_requests=pandas.DataFrame(columns=["hotel_id", "price", "stock", "city", "date", "language", "mobile", "avatar_id", "request_number"])"""
"""pricing_requests.to_csv('pricing_requests_done.csv', index=False)"""

# %%
our_requests = pandas.read_csv('all_our_requests_done.csv', header = 0)
pricing_requests = pandas.read_csv('pricing_requests_done.csv', header = 0)

request_num =our_requests.shape[0]


idx_available = [8,1,2,3,9,10]
nb_request = 1
chosen_idx = np.random.choice(idx_available, replace = False, size = nb_request)

import time

for i in chosen_idx: #le chosen index correspond à une reqête 
    print(i)
    date = datetime.today().strftime('%Y-%m-%d_%H:%M:%S')
    days= np.random.choice(range(0, 45), number_days, replace=False)
    j=0
    for iter_days in (sorted(days, reverse=True)):
        
        #création avatar
        time.sleep(1) #pour ne pas avoir 2 avatar de noms identiques
        name = date + '_avatar'     
        #à créer l'avatar 
        a = requests.post(path(f'avatars/{user_id}/{name}'))
        
        #paramètres
        city=str(df.iloc[i,:]["city"])
        mobile=df.iloc[i,:]["mobile"]
        language=str(df.iloc[i,:]["language"])
        
        #paramètres requetes
        params = {
            "avatar_name": name,
            "language": language,
            "city": city,
            "date": iter_days,
            "mobile": mobile,
        }
        
        print(city)
        print(language)
        
"""     request_num +=1
        r1 = requests.get(path(f"pricing/{user_id}"), params=params)
        array_to_add = pd.DataFrame(r1.json()['prices']).assign(**r1.json()['request'])
        array_to_add = array_to_add.assign(request_number=request_num)
       
        
        pricing_requests = pd.concat([pricing_requests, array_to_add])
        
        
        add_to_our_requests = pandas.DataFrame([[r1.json()['request']['avatar_id'], mobile, language, city, iter_days,  i]], 
                                       columns=["avatar_id", "mobile", "language", "city", "date", "id_request"])
        our_requests = pandas.concat([our_requests, add_to_our_requests], ignore_index=True)
        

pricing_requests.to_csv('pricing_requests_done.csv', index=False)
our_requests.to_csv('all_our_requests_done.csv', index=False)"""
"""            
        globals()[f"r{i}"]= requests.post(path(f"avatars/{user_id}/{name}"))
        r1.json()
        pricing_requests.append(globals()[f"r{i}"])
        """


"""requests = [r1, r2]
for r in requests:
    pricing_requests.append(
        pd.DataFrame(r.json()['prices']).assign(**r.json()['request'])
    )

pricing_requests = pd.concat(pricing_requests)
pricing_requests.head()"""
# Out:
# 2
# copenhagen
# austrian
# "requests = [r1, r2]\nfor r in requests:\n    pricing_requests.append(\n        pd.DataFrame(r.json()['prices']).assign(**r.json()['request'])\n    )\n\npricing_requests = pd.concat(pricing_requests)\npricing_requests.head()"

# %%
for i in range (10):
    for j in range 
     globals()[f"variable1{i}{j}"]=i
variable11
# Out:
#   File "C:\Users\flavi\AppData\Local\Temp/ipykernel_37076/1312043037.py", line 2
#     for j in range
#                    ^
# SyntaxError: invalid syntax

# %%
array_to_add=pd.DataFrame(r1.json()['prices']).assign(**r1.json()['request'])
pricing_requests = pd.concat([pricing_requests, array_to_add])
        
        
add_to_our_requests=pandas.DataFrame([[r1.json()['request']['avatar_id'], mobile, language, city, iter_days,  i]], 
                                       columns=["avatar_id", "mobile", "language", "city", "date", "id_request"])
our_requests=pandas.concat([our_requests, add_to_our_requests], ignore_index=True)
        

pricing_requests.to_csv('pricing_requests_done.csv', index=False)
our_requests.to_csv('all_our_requests_done.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_37076/2015397907.py in <module>
#      11
#      12
# ---> 13 pricing_requests.to_csv('pricing_requests_done.csv', index=False)
#      14 our_requests.to_csv('all_our_requests_done.csv', index=False)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3464         )
#    3465
# -> 3466         return DataFrameRenderer(formatter).to_csv(
#    3467             path_or_buf,
#    3468             line_terminator=line_terminator,
#
# ...

# %%
pd.DataFrame(r1.json()['prices'])
our_requests.to_csv('all_our_requests_done.csv', index=False)

# %%
r1.json()['request']['avatar_id']
# Out:
# 6059

# %%
our_requests = pandas.read_csv('all_our_requests_done.csv', header = 0)
our_requests.shape[0]
# Out:
# 4

# %%
print(our_requests)
request_num =our_requests.shape[0]
print(request_num)
# Out:
#    avatar_id  mobile  language        city  date  id_request
# 0       6056       1  austrian   amsterdam    39           1
# 1       6057       1  austrian  copenhagen     9           3
# 2       6058       0  austrian  copenhagen     9           2
# 3       6059       0  austrian   amsterdam     9           0
# 4       6093       1     paris    austrian    12           1
# 5      21244       0  austrian        rome    28           8
# 6      26978       0  austrian        rome     2           4
# 7

# %%
print(our_requests.shape[0])
# Out:
# 5

# %%
df = array_to_add.assign(request_num=5)
df
# Out:
#      hotel_id  price  stock  city  date  language  mobile  avatar_id  \
# 0         636    100     44  rome    28  austrian       0      21244
# 1         552     97     47  rome    28  austrian       0      21244
# 2         396    101     40  rome    28  austrian       0      21244
# 3         486    176     55  rome    28  austrian       0      21244
# 4         856     75     11  rome    28  austrian       0      21244
# ..        ...    ...    ...   ...   ...       ...     ...        ...
# 123        48     67     53  rome    28  austrian       0      21244
# 124       286    114     32  rome    28  austrian       0      21244
# 125       686     87     22  rome    28  austrian       0      21244
# 126       563    182     52  rome    28  austrian       0      21244
# 127       701     73     27  rome    28  austrian       0      21244
#
#      request_num
# 0              5
# 1              5
# 2              5
# 3              5
# 4              5
# ..           ...
# ...

# %%
our_requests = pandas.read_csv('all_our_requests_done.csv', header = 0)
pricing_requests = pandas.read_csv('pricing_requests_done.csv', header = 0)

request_num =our_requests.shape[0]
print(request_num)
# Out:
# 7

# %%
hotel_id,price,stock,city,date,language,mobile,avatar_id,request_number
105,144,102,amsterdam,39,austrian,1,6056,1
880,113,81,amsterdam,39,austrian,1,6056,1
588,172,108,amsterdam,39,austrian,1,6056,1
352,105,84,amsterdam,39,austrian,1,6056,1
925,103,83,amsterdam,39,austrian,1,6056,1
346,174,143,amsterdam,39,austrian,1,6056,1
570,101,82,amsterdam,39,austrian,1,6056,1
366,80,82,amsterdam,39,austrian,1,6056,1
567,75,40,amsterdam,39,austrian,1,6056,1
230,106,79,amsterdam,39,austrian,1,6056,1
450,173,151,amsterdam,39,austrian,1,6056,1
223,146,100,amsterdam,39,austrian,1,6056,1
750,110,40,amsterdam,39,austrian,1,6056,1
969,80,45,amsterdam,39,austrian,1,6056,1
752,246,211,amsterdam,39,austrian,1,6056,1
557,116,82,amsterdam,39,austrian,1,6056,1
510,260,192,amsterdam,39,austrian,1,6056,1
971,147,102,amsterdam,39,austrian,1,6056,1
760,171,150,amsterdam,39,austrian,1,6056,1
628,159,102,amsterdam,39,austrian,1,6056,1
369,73,41,amsterdam,39,austrian,1,6056,1
783,87,40,amsterdam,39,austrian,1,6056,1
77,247,193,amsterdam,39,austrian,1,6056,1
387,241,207,amsterdam,39,austrian,1,6056,1
45,153,100,amsterdam,39,austrian,1,6056,1
311,108,45,amsterdam,39,austrian,1,6056,1
548,241,220,amsterdam,39,austrian,1,6056,1
779,181,148,amsterdam,39,austrian,1,6056,1
835,108,84,amsterdam,39,austrian,1,6056,1
307,104,78,amsterdam,39,austrian,1,6056,1
515,249,197,amsterdam,39,austrian,1,6056,1
253,248,192,amsterdam,39,austrian,1,6056,1
591,247,206,amsterdam,39,austrian,1,6056,1
